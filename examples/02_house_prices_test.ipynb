# %%
from dstools.dataset import load_house_prices
from dstools.preprocess import Pipeline
from scipy import stats
import pandas as pd

pd.set_option('display.max_columns', 500)
train_ini, test = load_house_prices()

# %%
test = test.drop(columns="Id")
test
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0             20       RH         80.0    11622   Pave   NaN      Reg
# 1             20       RL         81.0    14267   Pave   NaN      IR1
# 2             60       RL         74.0    13830   Pave   NaN      IR1
# 3             60       RL         78.0     9978   Pave   NaN      IR1
# 4            120       RL         43.0     5005   Pave   NaN      IR1
# ...          ...      ...          ...      ...    ...   ...      ...
# 1454         160       RM         21.0     1936   Pave   NaN      Reg
# 1455         160       RM         21.0     1894   Pave   NaN      Reg
# 1456          20       RL        160.0    20000   Pave   NaN      Reg
# 1457          85       RL         62.0    10441   Pave   NaN      Reg
# 1458          60       RL         74.0     9627   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# ...

# %%
p = Pipeline.load("pipeline.pkl")

# %%
X_test, y_test = p(test)

# %%
X_test.head(5)
# Out:
#    MSSubClass  LotFrontage  LotArea  Street  LotShape  Utilities  LandSlope  \
# 0          20         80.0    11622       1         0          0          0
# 1          20         81.0    14267       1         1          0          0
# 2          60         74.0    13830       1         1          0          0
# 3          60         78.0     9978       1         1          0          0
# 4         120         43.0     5005       1         1          0          0
#
#    BldgType  OverallQual  OverallCond  YearBuilt  YearRemodAdd  MasVnrArea  \
# 0         0            5            6       1961          1961         0.0
# 1         0            6            6       1958          1958       108.0
# 2         0            5            5       1997          1998         0.0
# 3         0            6            6       1998          1998        20.0
# 4         4            8            5       1992          1992         0.0
#
# ...

# %%
y_test
# Out:
# array([131212.02, 179318.9 , 187683.03, ..., 177563.9 , 106697.93,
#        241310.44], dtype=float32)
